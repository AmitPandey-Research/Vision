# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os

# %%
img = cv2.imread('../src/bond.jpg')

# %%
a = os.path.isdir('../../assignment-0-AmitPandey-Research')
a
# Out:
# True

# %%
plt.imshow(img)

# %%
pwd
# Out:
# '/home/amitpandey/iiith/CV-2021/assignments/assignment-0-AmitPandey-Research/src'
